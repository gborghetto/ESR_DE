# %%
# Load getdist and plot chains from Cobaya output
from getdist import MCSamples, plots, loadMCSamples
import os


samples = loadMCSamples('./chains/quintessence_camb',settings={'ignore_rows': 0.33})

print('Parameter names available:', samples.getParamNames().list())
# Out:
# WARNING:root:outlier fraction 0.018876828692779613
# ./chains/quintessence_camb.4.txt
# ./chains/quintessence_camb.1.txt
# ./chains/quintessence_camb.3.txt
# ./chains/quintessence_camb.2.txt
# Removed 0.33 as burn in
# Parameter names available: ['omch2', 'ombh2', 'H0', 'lambda_phi', 'chi2__BAO', 'chi2__SN', 'chi2_total', 'omegam', 'rdrag', 'hrd', 'chi2__CMB', 'chi2', 'chi2__bao.desi_dr2.desi_bao_all', 'chi2__sn.union3', 'chi2__cmb_lite_3d']

# %%
# # Triangle plot for first up-to-6 parameters
# param_names = [p.name for p in samples.getParamNames().list()][:6]
# print('Using parameters for triangle plot:', param_names)

param_names = ['ombh2', 'omch2', 'H0','lambda_phi']

param_limits = {
    'ombh2': (0.0217, 0.023),
    'omch2': (0.1135, 0.12),
    'H0': (64, 72),
    'n': (0., 1.5),
}

g = plots.getSubplotPlotter()
g.triangle_plot(samples, param_names, filled=True) #,param_limits=param_limits)
out_triangle = 'mcmc_triangle.pdf'
print('Saving triangle plot to', out_triangle)
# g.export(out_triangle)


for p in param_names:
    print(samples.getInlineLatex(p,limit=2))

# # 1D marginals for each parameter separately
# for pname in samples.getParamNames().list():
#     name = pname.name
#     g = plots.getSinglePlotter()
#     g.plot_1d(samples, [name])
#     out1d = f'mcmc_1d_{name}.png'
#     print('Saving 1D marginal to', out1d)
#     g.export(out1d)
# Out:
# Saving triangle plot to mcmc_triangle.pdf
# \Omega_\mathrm{b} h^2 = 0.02244^{+0.00025}_{-0.00024}
# \Omega_\mathrm{c} h^2 = 0.1170^{+0.0017}_{-0.0016}
# H_0 = 67.2^{+1.4}_{-1.6}
# \lambda_\phi < 1.03

# %%
# param_names = [p.name for p in samples.getParamNames().list()][:6]
# print('Using parameters for triangle plot:', param_names)

param_names = ['omegam', 'H0','lambda_phi','hrd']

g = plots.getSubplotPlotter()
g.triangle_plot(samples, param_names, filled=True)
out_triangle = 'mcmc_triangle.pdf'
print('Saving triangle plot to', out_triangle)
# g.export(out_triangle)


for p in param_names:
    print(samples.getInlineLatex(p,limit=2))

# # 1D marginals for each parameter separately
# for pname in samples.getParamNames().list():
#     name = pname.name
#     g = plots.getSinglePlotter()
#     g.plot_1d(samples, [name])
#     out1d = f'mcmc_1d_{name}.png'
#     print('Saving 1D marginal to', out1d)
#     g.export(out1d)
# Out:
# Saving triangle plot to mcmc_triangle.pdf
# \Omega_\mathrm{m} = 0.309^{+0.014}_{-0.013}
# H_0 = 67.2^{+1.4}_{-1.6}
# \lambda_\phi < 1.03
# hr_d = 99.3^{+2.1}_{-2.3}
