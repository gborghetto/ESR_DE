# %%
# Load getdist and plot chains from Cobaya output
from getdist import MCSamples, plots, loadMCSamples
import os

chains_dir = os.path.join(os.getcwd(), 'chains')
root = 'test_solver_v2'


samples = loadMCSamples('./chains/test_solver_exp',settings={'ignore_rows': 0.5})

print('Parameter names available:', samples.getParamNames().list())
# Out:
# WARNING:root:outlier fraction 0.12037037037037036
# ./chains/test_solver_exp.1.txt
# ./chains/test_solver_exp.2.txt
# ./chains/test_solver_exp.3.txt
# ./chains/test_solver_exp.4.txt
# Removed 0.5 as burn in
# Parameter names available: ['omch2', 'ombh2', 'H0', 'lambda_phi', 'chi2__BAO', 'chi2__SN', 'chi2_total', 'omegam', 'rdrag', 'hrd', 'chi2', 'chi2__like_ombh2_BBN', 'chi2__bao.desi_dr2.desi_bao_all', 'chi2__sn.union3']

# %%
# # Triangle plot for first up-to-6 parameters
# param_names = [p.name for p in samples.getParamNames().list()][:6]
# print('Using parameters for triangle plot:', param_names)

param_names = ['ombh2', 'omch2', 'H0','lambda_phi']

g = plots.getSubplotPlotter()
g.triangle_plot(samples, param_names, filled=True)
out_triangle = 'mcmc_triangle.pdf'
print('Saving triangle plot to', out_triangle)
# g.export(out_triangle)


for p in param_names:
    print(samples.getInlineLatex(p,limit=2))

# # 1D marginals for each parameter separately
# for pname in samples.getParamNames().list():
#     name = pname.name
#     g = plots.getSinglePlotter()
#     g.plot_1d(samples, [name])
#     out1d = f'mcmc_1d_{name}.png'
#     print('Saving 1D marginal to', out1d)
#     g.export(out1d)
# Out:
# WARNING:root:2D kernel density bandwidth optimizer failed for ombh2, H0. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for H0, lambda_phi. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for H0, lambda_phi. Using fallback width: f(a) and f(b) must have different signs
# Saving triangle plot to mcmc_triangle.pdf
# \Omega_\mathrm{b} h^2 < 0.0211
# \Omega_\mathrm{c} h^2 < 0.114
# H_0 > 65.5
# \lambda_\phi > 0.933

# %%
# param_names = [p.name for p in samples.getParamNames().list()][:6]
# print('Using parameters for triangle plot:', param_names)

param_names = ['omegam', 'H0','lambda_phi','hrd']

g = plots.getSubplotPlotter()
g.triangle_plot(samples, param_names, filled=True)
out_triangle = 'mcmc_triangle.pdf'
print('Saving triangle plot to', out_triangle)
# g.export(out_triangle)


for p in param_names:
    print(samples.getInlineLatex(p,limit=2))

# # 1D marginals for each parameter separately
# for pname in samples.getParamNames().list():
#     name = pname.name
#     g = plots.getSinglePlotter()
#     g.plot_1d(samples, [name])
#     out1d = f'mcmc_1d_{name}.png'
#     print('Saving 1D marginal to', out1d)
#     g.export(out1d)
# Out:
# WARNING:root:2D kernel density bandwidth optimizer failed for H0, lambda_phi. Using fallback width: f(a) and f(b) must have different signs
# Saving triangle plot to mcmc_triangle.pdf
# \Omega_\mathrm{m} < 0.307
# H_0 > 65.5
# \lambda_\phi > 0.933
# hr_d > 112
